# %%
import pandas as pd
import numpy as np
import os
import json
from itertools import compress
import re

# %% [markdown]
# ## <font color='red'>Initializing Data</font>

# %% [markdown]
# ### Useful functions to download data from Google Analytics

# %%
def get_data(folder_path):
    """ It gives all the data in a folder of a day """
    def open_json(path):
        with open(path) as f:
            data = json.load(f)
        return data    

    directory = os.listdir(folder_path)
    df_list = []
    #Each df takes the name of the given event
    for i in range(len(directory)):
        filename_json = directory[i]
        if filename_json.endswith(".json"):
            file_path = folder_path + '/' + filename_json 
            data      = open_json(file_path)
            #print(data)
            filename  = pd.DataFrame(data).event_name.unique()[0] + '_' + folder_path.split('/')[-1]
        
            globals()[filename] = data
            df_list.append(filename)
     
    print('In this folder there are ' + str(len(directory)) + ' df:\n' + str(df_list))   
    
    return df_list

# %%
def unnest_column(df, nested_key='key'):
    """ Unnesting all the value in the column "event_params" """
    #Local function that unnest the single value
    def flat_nested_columnn_value(nested_key, nested_value):
        return pd.DataFrame(nested_value).set_index(nested_key).transpose().reset_index()
    
    #Iterating it over each row
    col_to_unnest = df.iloc[:,-1] 
    df_in = pd.DataFrame()
    for row in df.index:
        df_flat = flat_nested_columnn_value(nested_key, col_to_unnest[row])
        df_in = pd.concat([df_in, df_flat]) 
    
    #It returns another df with all new features that are still dictionary 
    df_in = df_in.drop(columns='index').set_index(df.index)
    return df_in


def flat_a_row(df, row_index):
    """ Flattening the dictonaries inside the unnested column (transformed in a df) """
    #Local function that flats a single dictonary
    def flat_dict_value(column_name, column_value):
        dict_to_df = pd.Series(column_value).to_frame().transpose()
        dict_to_df.columns = [column_name + '_' + str(name) for name in dict_to_df.columns]
        return dict_to_df
    #Iterating over each column
    df_row = pd.DataFrame()
    for col in df.columns:
        df_flat = flat_dict_value(col, df.loc[row_index,col])
        df_row = pd.concat([df_row, df_flat], axis=1)
    
    return df_row

def flat_unnested_column(df_unnested, df_mother):
    """ Iterating over each row """
    df_out = pd.DataFrame()
    for row in df_unnested.index:
        df_flat = flat_a_row(df_unnested, row)
        df_out = pd.concat([df_out, df_flat]) 

    df_out = df_out.set_index(df_mother.index)
    return df_out


def unnest(df):
    """ Concatenate the original data with the unnested ones """
    column_to_df = unnest_column(df)
    flatten = flat_unnested_column(column_to_df, df)
    return pd.concat([df, flatten], axis=1).drop(columns='event_params') 


def get_df(folder_path):
    """ Return all the unnested and flatten data in a day"""
    df_list = get_data(folder_path)
    for df in df_list:
        print('..' + df + '..')
        globals()[df] = unnest(pd.DataFrame(globals()[df]))#[Filters[df]]

# %% [markdown]
# With get_data function we download all the dataframes of a day contained in a folder of the form: "datos-first_day-last_day"

# %%
df_list = get_data('./datos-01abr-07abr/20210403')
# Out:
# In this folder there are 9 df:
# ['FILTER_ADDED_20210403', 'RESTAURANT_BLACKLISTED_20210403', 'HOME_FILTERS_20210403', 'RESTAURANT_FAVOURITE_20210403', 'RESTAURANT_ACTION_20210403', 'MY_FAVS_FILTER_ADDED_20210403', 'view_item_20210403', 'MY_FAVS_REMOVE_RESTAURANT_20210403']

# %% [markdown]
# Showing unnested dataframes: get_df generates global variables

# %%
get_df('./datos-01abr-07abr/20210403')
# Out:
# In this folder there are 9 df:
# ['FILTER_ADDED_20210403', 'RESTAURANT_BLACKLISTED_20210403', 'HOME_FILTERS_20210403', 'RESTAURANT_FAVOURITE_20210403', 'RESTAURANT_ACTION_20210403', 'MY_FAVS_FILTER_ADDED_20210403', 'view_item_20210403', 'MY_FAVS_REMOVE_RESTAURANT_20210403']
# ..FILTER_ADDED_20210403..
# ..RESTAURANT_BLACKLISTED_20210403..
# ..HOME_FILTERS_20210403..
# ..RESTAURANT_FAVOURITE_20210403..
# ..RESTAURANT_ACTION_20210403..
# ..MY_FAVS_FILTER_ADDED_20210403..
# ..view_item_20210403..
# ..MY_FAVS_REMOVE_RESTAURANT_20210403..

# %%
RESTAURANT_ACTION_20210403.head()
# Out:
#     event_timestamp         event_name                    user_pseudo_id  \
# 0  1617482162766918  RESTAURANT_ACTION  08f523f6c5269ac261fde43a6b8612fb
# 1  1617431480539984  RESTAURANT_ACTION  2da3f0dd8e33aca615faacca7d9edcb6
# 2  1617405052388807  RESTAURANT_ACTION  7a195ff4383c72165c4f2805d5a2ba3a
# 3  1617405070367815  RESTAURANT_ACTION  7a195ff4383c72165c4f2805d5a2ba3a
# 4  1617472615061355  RESTAURANT_ACTION  165332d1c3ac5fff31036c8615d9667c
#
#   ga_session_id_string_value ga_session_id_int_value  \
# 0                       None              1617481828
# 1                       None              1617431395
# 2                       None              1617404966
# 3                       None              1617404966
# 4                       None              1617472164
#
#   ga_session_id_float_value ga_session_id_double_value  \
# 0                      None                       None
# 1                      None                       None
# 2                      None                       None
# 3                      None                       None
# 4                      None                       None
#
#   firebase_screen_id_string_value firebase_screen_id_int_value  \
# 0                            None         -6699667872550144056
# 1                            None           873550206509334963
# 2                            None          7671154372456552128
# 3                            None          7671154372456552131
# 4                            None           454524847707602982
#
#   firebase_screen_id_float_value firebase_screen_id_double_value  \
# 0                           None                            None
# 1                           None                            None
# 2                           None                            None
# 3                           None                            None
# 4                           None                            None
#
#   engaged_session_event_string_value engaged_session_event_int_value  \
# 0                               None                               1
# 1                               None                               1
# 2                               None                               1
# 3                               None                               1
# 4                                NaN                             NaN
#
#   engaged_session_event_float_value engaged_session_event_double_value  \
# 0                              None                               None
# 1                              None                               None
# 2                              None                               None
# 3                              None                               None
# 4                               NaN                                NaN
#
#   action_string_value action_int_value action_float_value action_double_value  \
# 0                menu             None               None                None
# 1                menu             None               None                None
# 2          curated_by             None               None                None
# 3           instagram             None               None                None
# 4           instagram             None               None                None
#
#   firebase_screen_string_value firebase_screen_int_value  \
# 0            RestaurantDetails                      None
# 1            RestaurantDetails                      None
# 2            RestaurantDetails                      None
# 3            RestaurantDetails                      None
# 4            RestaurantDetails                      None
#
#   firebase_screen_float_value firebase_screen_double_value  \
# 0                        None                         None
# 1                        None                         None
# 2                        None                         None
# 3                        None                         None
# 4                        None                         None
#
#   timestamp_string_value timestamp_int_value timestamp_float_value  \
# 0                   None                None                  None
# 1                   None                None                  None
# 2                   None                None                  None
# 3                   None                None                  None
# 4                   None                None                  None
#
#   timestamp_double_value firebase_screen_class_string_value  \
# 0        1617482159758.0                  RestaurantDetails
# 1        1617431480078.0                  RestaurantDetails
# 2        1617405051301.0                  RestaurantDetails
# 3        1617405069354.0                  RestaurantDetails
# 4        1617472615050.0                  RestaurantDetails
#
#   firebase_screen_class_int_value firebase_screen_class_float_value  \
# 0                            None                              None
# 1                            None                              None
# 2                            None                              None
# 3                            None                              None
# 4                            None                              None
#
#   firebase_screen_class_double_value firebase_event_origin_string_value  \
# 0                               None                                app
# 1                               None                                app
# 2                               None                                app
# 3                               None                                app
# 4                               None                                app
#
#   firebase_event_origin_int_value firebase_event_origin_float_value  \
# 0                            None                              None
# 1                            None                              None
# 2                            None                              None
# 3                            None                              None
# 4                            None                              None
#
#   firebase_event_origin_double_value     name_string_value name_int_value  \
# 0                               None  La Maruca Castellana           None
# 1                               None               Benares           None
# 2                               None            Concepto X           None
# 3                               None            Concepto X           None
# 4                               None               Benares           None
#
#   name_float_value name_double_value id_string_value id_int_value  \
# 0             None              None             497         None
# 1             None              None             403         None
# 2             None              None             451         None
# 3             None              None             451         None
# 4             None              None             403         None
#
#   id_float_value id_double_value ga_session_number_string_value  \
# 0           None            None                           None
# 1           None            None                           None
# 2           None            None                           None
# 3           None            None                           None
# 4           None            None                           None
#
#   ga_session_number_int_value ga_session_number_float_value  \
# 0                           1                          None
# 1                           1                          None
# 2                           2                          None
# 3                           2                          None
# 4                           1                          None
#
#   ga_session_number_double_value  engaged_session_event_0
# 0                           None                      NaN
# 1                           None                      NaN
# 2                           None                      NaN
# 3                           None                      NaN
# 4                           None                      NaN

# %% [markdown]
# ### Selecting the relevant columns

# %%
Common_cols                    = ['event_name', 'event_timestamp', 'user_pseudo_id', 'firebase_screen_string_value']

cols_FILTER_ADDED              = Common_cols + ['type_string_value'] 

cols_view_item                 = Common_cols + ['item_name_string_value'] 
                              
cols_CARD_SWIPE                = Common_cols + ['name_string_value', 'dir_string_value']

cols_RESTAURANT_ACTION         = Common_cols + ['name_string_value', 'action_string_value']

cols_RESTAURANT_BLACKLISTED    = Common_cols + ['name_string_value']

cols_HOME_FILTERS              = Common_cols + ['vibes_string_value']

cols_RESTAURANT_FAVOURITE      = Common_cols + ['name_string_value']

cols_MY_FAVS_REMOVE_RESTAURANT = Common_cols + ['name_string_value']

cols_MY_FAVS_FILTER_ADDED      = Common_cols + ['type_string_value']

Filters = {'FILTER_ADDED':cols_FILTER_ADDED, 'view_item':cols_view_item, 
           'CARD_SWIPE':cols_CARD_SWIPE, 'RESTAURANT_ACTION':cols_RESTAURANT_ACTION, 
           'RESTAURANT_BLACKLISTED':cols_RESTAURANT_BLACKLISTED, 
           'HOME_FILTERS':cols_HOME_FILTERS, 'RESTAURANT_FAVOURITE':cols_RESTAURANT_FAVOURITE,
           'MY_FAVS_REMOVE_RESTAURANT':cols_MY_FAVS_REMOVE_RESTAURANT,
           'MY_FAVS_FILTER_ADDED':cols_MY_FAVS_FILTER_ADDED}

# %%
def filter_columns(df_list):
    """ It filters the relevant columns for a list of day dataframes """    
    #Add user_id when there is
    Filters_list = Filters.copy()
    for df in df_list:
        data = globals()[df]
        if 'user_id' in data.columns:
            filter_key = df[:len(df) - 9]
            Filters_list[filter_key] = Filters_list[filter_key] + ['user_id'] 
            print(Filters_list[filter_key])

    for df in df_list:
        filter_key = df[:len(df) - 9]
        globals()[df] = (globals()[df])[Filters_list[filter_key]]
        #Rename view_item column:
        if filter_key == 'view_item':
            globals()[df].rename(columns={'item_name_string_value': 'name_string_value'}, inplace=True)
    return

# %% [markdown]
# Example of a data of a day

# %%
data_day = pd.concat([FILTER_ADDED_20210403, view_item_20210403, RESTAURANT_ACTION_20210403,
            RESTAURANT_BLACKLISTED_20210403, HOME_FILTERS_20210403, RESTAURANT_FAVOURITE_20210403,\
                      MY_FAVS_FILTER_ADDED_20210403,MY_FAVS_REMOVE_RESTAURANT_20210403]).reset_index(drop=True)

# %%
data_day.head()
# Out:
#     event_timestamp    event_name                    user_pseudo_id  \
# 0  1617482034296969  FILTER_ADDED  08f523f6c5269ac261fde43a6b8612fb
# 1  1617405037559801  FILTER_ADDED  7a195ff4383c72165c4f2805d5a2ba3a
# 2  1617472666560363  FILTER_ADDED  165332d1c3ac5fff31036c8615d9667c
# 3  1617472696925374  FILTER_ADDED  165332d1c3ac5fff31036c8615d9667c
# 4  1617465985004581  FILTER_ADDED  ece89f49d06509154cce92c727bd1cce
#
#   ga_session_id_string_value ga_session_id_int_value  \
# 0                       None              1617481828
# 1                       None              1617404966
# 2                       None              1617472164
# 3                       None              1617472164
# 4                       None              1617465658
#
#   ga_session_id_float_value ga_session_id_double_value  \
# 0                      None                       None
# 1                      None                       None
# 2                      None                       None
# 3                      None                       None
# 4                      None                       None
#
#   error_value_string_value error_value_int_value error_value_float_value  \
# 0             FILTER_ADDED                  None                    None
# 1             FILTER_ADDED                  None                    None
# 2             FILTER_ADDED                  None                    None
# 3             FILTER_ADDED                  None                    None
# 4             FILTER_ADDED                  None                    None
#
#   error_value_double_value firebase_event_origin_string_value  \
# 0                     None                                app
# 1                     None                                app
# 2                     None                                app
# 3                     None                                app
# 4                     None                                app
#
#   firebase_event_origin_int_value firebase_event_origin_float_value  \
# 0                            None                              None
# 1                            None                              None
# 2                            None                              None
# 3                            None                              None
# 4                            None                              None
#
#   firebase_event_origin_double_value type_string_value type_int_value  \
# 0                               None          Española           None
# 1                               None      Menos de 50€           None
# 2                               None               Sol           None
# 3                               None               Sol           None
# 4                               None         La Latina           None
#
#   type_float_value type_double_value engaged_session_event_string_value  \
# 0             None              None                               None
# 1             None              None                               None
# 2             None              None                                NaN
# 3             None              None                                NaN
# 4             None              None                               None
#
#   engaged_session_event_int_value engaged_session_event_float_value  \
# 0                               1                              None
# 1                               1                              None
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                               1                              None
#
#   engaged_session_event_double_value id_string_value id_int_value  \
# 0                               None              19         None
# 1                               None              21         None
# 2                                NaN              40         None
# 3                                NaN              40         None
# 4                               None              25         None
#
#   id_float_value id_double_value firebase_screen_class_string_value  \
# 0           None            None                      SelectFilters
# 1           None            None                      SelectFilters
# 2           None            None                      SelectFilters
# 3           None            None                      SelectFilters
# 4           None            None                        TinderCards
#
#   firebase_screen_class_int_value firebase_screen_class_float_value  \
# 0                            None                              None
# 1                            None                              None
# 2                            None                              None
# 3                            None                              None
# 4                            None                              None
#
#   firebase_screen_class_double_value firebase_screen_id_string_value  \
# 0                               None                            None
# 1                               None                            None
# 2                               None                            None
# 3                               None                            None
# 4                               None                            None
#
#   firebase_screen_id_int_value firebase_screen_id_float_value  \
# 0           -19002095382642162                           None
# 1          7671154372456552126                           None
# 2           454524847707602985                           None
# 3           454524847707602989                           None
# 4         -1307328247607765441                           None
#
#   firebase_screen_id_double_value ga_session_number_string_value  \
# 0                            None                           None
# 1                            None                           None
# 2                            None                           None
# 3                            None                           None
# 4                            None                           None
#
#   ga_session_number_int_value ga_session_number_float_value  \
# 0                           1                          None
# 1                           2                          None
# 2                           1                          None
# 3                           1                          None
# 4                           1                          None
#
#   ga_session_number_double_value firebase_screen_string_value  \
# 0                           None                SelectFilters
# 1                           None                SelectFilters
# 2                           None                SelectFilters
# 3                           None                SelectFilters
# 4                           None                  TinderCards
#
#   firebase_screen_int_value firebase_screen_float_value  \
# 0                      None                        None
# 1                      None                        None
# 2                      None                        None
# 3                      None                        None
# 4                      None                        None
#
#   firebase_screen_double_value timestamp_string_value timestamp_int_value  \
# 0                         None                   None                None
# 1                         None                   None                None
# 2                         None                   None                None
# 3                         None                   None                None
# 4                         None                   None                None
#
#   timestamp_float_value timestamp_double_value firebase_error_string_value  \
# 0                  None      1.617482031289E12                        None
# 1                  None      1.617405036546E12                        None
# 2                  None      1.617472666554E12                        None
# 3                  None      1.617472696918E12                        None
# 4                  None      1.617465984995E12                        None
#
#   firebase_error_int_value firebase_error_float_value  \
# 0                       21                       None
# 1                       21                       None
# 2                       21                       None
# 3                       21                       None
# 4                       21                       None
#
#   firebase_error_double_value  engaged_session_event_0 item_id_string_value  \
# 0                        None                      NaN                  NaN
# 1                        None                      NaN                  NaN
# 2                        None                      NaN                  NaN
# 3                        None                      NaN                  NaN
# 4                        None                      NaN                  NaN
#
#   item_id_int_value item_id_float_value item_id_double_value  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#   item_category_string_value item_category_int_value  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
#
#   item_category_float_value item_category_double_value item_name_string_value  \
# 0                       NaN                        NaN                    NaN
# 1                       NaN                        NaN                    NaN
# 2                       NaN                        NaN                    NaN
# 3                       NaN                        NaN                    NaN
# 4                       NaN                        NaN                    NaN
#
#   item_name_int_value item_name_float_value item_name_double_value  \
# 0                 NaN                   NaN                    NaN
# 1                 NaN                   NaN                    NaN
# 2                 NaN                   NaN                    NaN
# 3                 NaN                   NaN                    NaN
# 4                 NaN                   NaN                    NaN
#
#   action_string_value action_int_value action_float_value action_double_value  \
# 0                 NaN              NaN                NaN                 NaN
# 1                 NaN              NaN                NaN                 NaN
# 2                 NaN              NaN                NaN                 NaN
# 3                 NaN              NaN                NaN                 NaN
# 4                 NaN              NaN                NaN                 NaN
#
#   name_string_value name_int_value name_float_value name_double_value  \
# 0               NaN            NaN              NaN               NaN
# 1               NaN            NaN              NaN               NaN
# 2               NaN            NaN              NaN               NaN
# 3               NaN            NaN              NaN               NaN
# 4               NaN            NaN              NaN               NaN
#
#   vibes_string_value vibes_int_value vibes_float_value vibes_double_value  \
# 0                NaN             NaN               NaN                NaN
# 1                NaN             NaN               NaN                NaN
# 2                NaN             NaN               NaN                NaN
# 3                NaN             NaN               NaN                NaN
# 4                NaN             NaN               NaN                NaN
#
#   option_string_value option_int_value option_float_value option_double_value  \
# 0                 NaN              NaN                NaN                 NaN
# 1                 NaN              NaN                NaN                 NaN
# 2                 NaN              NaN                NaN                 NaN
# 3                 NaN              NaN                NaN                 NaN
# 4                 NaN              NaN                NaN                 NaN
#
#    neighborhoods_0  session_engaged_0  vibes_0 neighborhoods_string_value  \
# 0              NaN                NaN      NaN                        NaN
# 1              NaN                NaN      NaN                        NaN
# 2              NaN                NaN      NaN                        NaN
# 3              NaN                NaN      NaN                        NaN
# 4              NaN                NaN      NaN                        NaN
#
#   neighborhoods_int_value neighborhoods_float_value  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#   neighborhoods_double_value session_engaged_string_value  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#   session_engaged_int_value session_engaged_float_value  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#   session_engaged_double_value  firebase_screen_0  firebase_screen_id_0  \
# 0                          NaN                NaN                   NaN
# 1                          NaN                NaN                   NaN
# 2                          NaN                NaN                   NaN
# 3                          NaN                NaN                   NaN
# 4                          NaN                NaN                   NaN
#
#    firebase_screen_class_0
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
filter_columns(['FILTER_ADDED_20210403', 'RESTAURANT_BLACKLISTED_20210403', 'HOME_FILTERS_20210403', 'RESTAURANT_FAVOURITE_20210403', 'RESTAURANT_ACTION_20210403', 'MY_FAVS_FILTER_ADDED_20210403', 'view_item_20210403', 'MY_FAVS_REMOVE_RESTAURANT_20210403'])

# %% [markdown]
# After filter_columns all dataframes have just the selected columns

# %%
RESTAURANT_ACTION_20210403.head()
# Out:
#           event_name   event_timestamp                    user_pseudo_id  \
# 0  RESTAURANT_ACTION  1617482162766918  08f523f6c5269ac261fde43a6b8612fb
# 1  RESTAURANT_ACTION  1617431480539984  2da3f0dd8e33aca615faacca7d9edcb6
# 2  RESTAURANT_ACTION  1617405052388807  7a195ff4383c72165c4f2805d5a2ba3a
# 3  RESTAURANT_ACTION  1617405070367815  7a195ff4383c72165c4f2805d5a2ba3a
# 4  RESTAURANT_ACTION  1617472615061355  165332d1c3ac5fff31036c8615d9667c
#
#   firebase_screen_string_value     name_string_value action_string_value
# 0            RestaurantDetails  La Maruca Castellana                menu
# 1            RestaurantDetails               Benares                menu
# 2            RestaurantDetails            Concepto X          curated_by
# 3            RestaurantDetails            Concepto X           instagram
# 4            RestaurantDetails               Benares           instagram

# %% [markdown]
# ### Putting all together to retrieve all the data from a folder of several days

# %%
def get_day_list(folder_path):
    """ Return the list of string name of data in a day but not the dataframes"""
    def open_json(path):
        with open(path) as f:
            data = json.load(f)
        return data    

    directory = os.listdir(folder_path)
    df_list = []
    #Each df takes the name of the given event
    for i in range(len(directory)):
        filename_json = directory[i]
        if filename_json.endswith(".json"):
            file_path = folder_path + '/' + filename_json 
            data      = open_json(file_path)
            #print(data)
            filename  = pd.DataFrame(data).event_name.unique()[0] + '_' + folder_path.split('/')[-1]
            df_list.append(filename)
         
    return df_list 



def get_week_data(week_folder_path, save=True):
    """ Finally it returns the week data frame """
    all_day_folders  = os.listdir(week_folder_path)[1:]
    #masking just the date folders
    mask = [s.isdigit() for s in all_day_folders]
    all_day_folders = list(compress(all_day_folders, mask))
    df_week = []
    for fold in all_day_folders:
        #getting all the dataframe for a day
        get_df(week_folder_path + '/' + fold)
        #getting the list of dataframe names
        df_list = get_day_list(week_folder_path + '/' + fold)
        #filtering the unecessary columns
        filter_columns(df_list)
        #concatenating all the dataframes obtaining a single day data
        df_day = []
        for df in df_list:
            df_day.append(globals()[df])
        day = pd.concat(df_day)
        #concatenating each day df obtaining a week df
        df_week.append(day)
    week = pd.concat(df_week)  
    
    if save==True:
        day1, day2 = re.findall(r'\d{2}\w{3}', week_folder_path)
        path_csv = 'week_{}_{}.csv'.format(day1, day2)
        week.to_csv(path_csv )
        
    return week

# %% [markdown]
# First week data

# %%
week = get_week_data('./datos-01mar-08mar') 
week

# %%
#week.to_csv('./week_01mar_08mar.csv')
week.head()
# Out:
#   event_name   event_timestamp                    user_pseudo_id  \
# 0  view_item  1615122075978494  cf787fe9a8f5cd3d0a7119e296920e96
# 1  view_item  1615122002536876  cf787fe9a8f5cd3d0a7119e296920e96
# 2  view_item  1615148229440659  C42314CB72C146BFB3A8A447A1F13F1A
# 3  view_item  1615152930412024  C42314CB72C146BFB3A8A447A1F13F1A
# 4  view_item  1615152981578048  C42314CB72C146BFB3A8A447A1F13F1A
#
#   firebase_screen_string_value name_string_value type_string_value  \
# 0            RestaurantDetails      Coquetto Bar               NaN
# 1            RestaurantDetails      Coquetto Bar               NaN
# 2            RestaurantDetails   El Señor Martín               NaN
# 3            RestaurantDetails         La Catapa               NaN
# 4            RestaurantDetails          La Monte               NaN
#
#   action_string_value vibes_string_value dir_string_value user_id
# 0                 NaN                NaN              NaN     NaN
# 1                 NaN                NaN              NaN     NaN
# 2                 NaN                NaN              NaN     NaN
# 3                 NaN                NaN              NaN     NaN
# 4                 NaN                NaN              NaN     NaN

# %%
week.shape
# Out:
# (21182, 10)

# %%
week.loc[:,'event_name'].unique()
# Out:
# array(['view_item', 'FILTER_ADDED', 'MY_FAVS_FILTER_ADDED',
#        'RESTAURANT_ACTION', 'RESTAURANT_FAVOURITE', 'HOME_FILTERS',
#        'MY_FAVS_REMOVE_RESTAURANT', 'CARD_SWIPE',
#        'RESTAURANT_BLACKLISTED'], dtype=object)

# %% [markdown]
# Second week data

# %%
week2 = get_week_data('./datos-09mar-31mar') 
week2
# Out:
# In this folder there are 8 df:
# ['MY_FAVS_FILTER_ADDED_20210309', 'MY_FAVS_REMOVE_RESTAURANT_20210309', 'CARD_SWIPE_20210309', 'RESTAURANT_ACTION_20210309', 'RESTAURANT_FAVOURITE_20210309', 'HOME_FILTERS_20210309', 'view_item_20210309', 'FILTER_ADDED_20210309']
# ..MY_FAVS_FILTER_ADDED_20210309..
# ..MY_FAVS_REMOVE_RESTAURANT_20210309..
# ..CARD_SWIPE_20210309..
# ..RESTAURANT_ACTION_20210309..
# ..RESTAURANT_FAVOURITE_20210309..
# ..HOME_FILTERS_20210309..
# ..view_item_20210309..
# ..FILTER_ADDED_20210309..
# In this folder there are 8 df:
# ['CARD_SWIPE_20210330', 'MY_FAVS_REMOVE_RESTAURANT_20210330', 'HOME_FILTERS_20210330', 'MY_FAVS_FILTER_ADDED_20210330', 'FILTER_ADDED_20210330', 'RESTAURANT_FAVOURITE_20210330', 'view_item_20210330', 'RESTAURANT_ACTION_20210330']
# ..CARD_SWIPE_20210330..
# ..MY_FAVS_REMOVE_RESTAURANT_20210330..
# ..HOME_FILTERS_20210330..
# ..MY_FAVS_FILTER_ADDED_20210330..
# ..FILTER_ADDED_20210330..
# ..RESTAURANT_FAVOURITE_20210330..
# ..view_item_20210330..
# ..RESTAURANT_ACTION_20210330..
# In this folder there are 7 df:
# ['view_item_20210312', 'RESTAURANT_FAVOURITE_20210312', 'FILTER_ADDED_20210312', 'MY_FAVS_REMOVE_RESTAURANT_20210312', 'RESTAURANT_ACTION_20210312', 'HOME_FILTERS_20210312', 'CARD_SWIPE_20210312']
# ..MY_FAVS_REMOVE_RESTAURANT_20210311..
# In this folder there are 7 df:
# ['RESTAURANT_FAVOURITE_20210327', 'HOME_FILTERS_20210327', 'MY_FAVS_FILTER_ADDED_20210327', 'CARD_SWIPE_20210327', 'MY_FAVS_REMOVE_RESTAURANT_20210327', 'view_item_20210327', 'RESTAURANT_ACTION_20210327']
# ..RESTAURANT_FAVOURITE_20210327..
# ..HOME_FILTERS_20210327..
# ..MY_FAVS_FILTER_ADDED_20210327..
# ..CARD_SWIPE_20210327..
# ..MY_FAVS_REMOVE_RESTAURANT_20210327..
# ..view_item_20210327..
# ..RESTAURANT_ACTION_20210327..
# In this folder there are 9 df:
# ['HOME_FILTERS_20210318', 'MY_FAVS_REMOVE_RESTAURANT_20210318', 'CARD_SWIPE_20210318', 'FILTER_ADDED_20210318', 'MY_FAVS_FILTER_ADDED_20210318', 'RESTAURANT_ACTION_20210318', 'view_item_20210318', 'RESTAURANT_BLACKLISTED_20210318', 'RESTAURANT_FAVOURITE_20210318']
# ..HOME_FILTERS_20210318..
# ..MY_FAVS_REMOVE_RESTAURANT_20210318..
# ..CARD_SWIPE_20210318..
# ..FILTER_ADDED_20210318..
# ..MY_FAVS_FILTER_ADDED_20210318..
# ..RESTAURANT_ACTION_20210318..
# ..view_item_20210318..
# ..RESTAURANT_BLACKLISTED_20210318..
# ..RESTAURANT_FAVOURITE_20210318..
# In this folder there are 7 df:
# ['view_item_20210320', 'RESTAURANT_FAVOURITE_20210320', 'HOME_FILTERS_20210320', 'RESTAURANT_ACTION_20210320', 'MY_FAVS_REMOVE_RESTAURANT_20210320', 'FILTER_ADDED_20210320', 'CARD_SWIPE_20210320']
# ..view_item_20210320..
# ..RESTAURANT_FAVOURITE_20210320..
# ..HOME_FILTERS_20210320..
# ..RESTAURANT_ACTION_20210320..
# ..MY_FAVS_REMOVE_RESTAURANT_20210320..
# ..FILTER_ADDED_20210320..
# ..CARD_SWIPE_20210320..
# In this folder there are 7 df:
# ['HOME_FILTERS_20210321', 'view_item_20210321', 'RESTAURANT_ACTION_20210321', 'CARD_SWIPE_20210321', 'MY_FAVS_REMOVE_RESTAURANT_20210321', 'FILTER_ADDED_20210321', 'RESTAURANT_FAVOURITE_20210321']
# ..HOME_FILTERS_20210321..
# ..view_item_20210321..
# ..RESTAURANT_ACTION_20210321..
# ..CARD_SWIPE_20210321..
# ..MY_FAVS_REMOVE_RESTAURANT_20210321..
# ..FILTER_ADDED_20210321..
# ..RESTAURANT_FAVOURITE_20210321..
# In this folder there are 6 df:
# ['RESTAURANT_ACTION_20210326', 'RESTAURANT_FAVOURITE_20210326', 'FILTER_ADDED_20210326', 'CARD_SWIPE_20210326', 'view_item_20210326', 'HOME_FILTERS_20210326']
# ..RESTAURANT_ACTION_20210326..
# ..RESTAURANT_FAVOURITE_20210326..
# ..FILTER_ADDED_20210326..
# ..CARD_SWIPE_20210326..
# ..view_item_20210326..
# ..HOME_FILTERS_20210326..
# In this folder there are 6 df:
# ['RESTAURANT_FAVOURITE_20210319', 'HOME_FILTERS_20210319', 'CARD_SWIPE_20210319', 'view_item_20210319', 'RESTAURANT_ACTION_20210319', 'FILTER_ADDED_20210319']
# ..RESTAURANT_FAVOURITE_20210319..
# ..HOME_FILTERS_20210319..
# ..CARD_SWIPE_20210319..
# ..view_item_20210319..
# ..RESTAURANT_ACTION_20210319..
# ..FILTER_ADDED_20210319..
# In this folder there are 8 df:
# ['MY_FAVS_REMOVE_RESTAURANT_20
#
#     firebase_screen_string_value     type_string_value      name_string_value  \
# 0                  MyRestaurants  🍷Colectivo Decantado                    NaN
# 1                  SelectFilters    Para ir con amigos                    NaN
# 2                  SelectFilters          Menos de 50€                    NaN
# 3                  MyRestaurants             Salamanca                    NaN
# 4                  MyRestaurants    Para ir con amigos                    NaN
# ..                           ...                   ...                    ...
# 533                  TinderCards                   NaN            La Espumosa
# 534                  TinderCards                   NaN  El Perro y la Galleta
# 535            RestaurantDetails                   NaN              Bel Mondo
# 536                  TinderCards                   NaN              Bel Mondo
# 537                MyRestaurants                   NaN             Propaganda
#
#     dir_string_value action_string_value vibes_string_value
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
# ..               ...                 ...                ...
# 533              NaN                 NaN                NaN
# 534              NaN                 NaN                NaN
# 535              NaN                 NaN                NaN
# 536              NaN                 NaN                NaN
# 537              NaN                 NaN                NaN
#
# [141104 rows x 9 columns]

# %% [markdown]
# Third week data

# %%
week3 = get_week_data('./datos-16abr-31abr')
# Out:
# In this folder there are 8 df:
# ['MY_FAVS_REMOVE_RESTAURANT_20210422', 'MY_FAVS_FILTER_ADDED_20210422', 'FILTER_ADDED_20210422', 'view_item_20210422', 'CARD_SWIPE_20210422', 'RESTAURANT_FAVOURITE_20210422', 'HOME_FILTERS_20210422', 'RESTAURANT_ACTION_20210422']
# ..MY_FAVS_REMOVE_RESTAURANT_20210422..
# ..MY_FAVS_FILTER_ADDED_20210422..
# ..FILTER_ADDED_20210422..
# ..view_item_20210422..
# ..CARD_SWIPE_20210422..
# ..RESTAURANT_FAVOURITE_20210422..
# ..HOME_FILTERS_20210422..
# ..RESTAURANT_ACTION_20210422..
# In this folder there are 9 df:
# ['RESTAURANT_BLACKLISTED_20210423', 'view_item_20210423', 'MY_FAVS_REMOVE_RESTAURANT_20210423', 'HOME_FILTERS_20210423', 'RESTAURANT_ACTION_20210423', 'RESTAURANT_FAVOURITE_20210423', 'FILTER_ADDED_20210423', 'CARD_SWIPE_20210423', 'MY_FAVS_FILTER_ADDED_20210423']
# ..RESTAURANT_BLACKLISTED_20210423..
# ..view_item_20210423..
# ..MY_FAVS_REMOVE_RESTAURANT_20210423..
# ..HOME_FILTERS_20210423..
# ..RESTAURANT_ACTION_20210423..
# ..RESTAURANT_FAVOURITE_20210423..
# ..FILTER_ADDED_20210423..
# ..CARD_SWIPE_20210423..
# ..MY_FAVS_FILTER_ADDED_20210423..
# In this folder there are 8 df:
# ['MY_FAVS_REMOVE_RESTAURANT_20210424', 'HOME_FILTERS_20210424', 'RESTAURANT_FAVOURITE_20210424', 'CARD_SWIPE_20210424', 'MY_FAVS_FILTER_ADDED_20210424', 'view_item_20210424', 'RESTAURANT_ACTION_20210424', 'FILTER_ADDED_20210424']
# ..MY_FAVS_REMOVE_RESTAURANT_20210424..
# ..HOME_FILTERS_20210424..
# ..RESTAURANT_FAVOURITE_20210424..
# ..CARD_SWIPE_20210424..
# ..MY_FAVS_FILTER_ADDED_20210424..
# ..view_item_20210424..
# ..RESTAURANT_ACTION_20210424..
# ..FILTER_ADDED_20210424..
# In this folder there are 9 df:
# ['MY_FAVS_REMOVE_RESTAURANT_20
# ..view_item_20210419..
# ..RESTAURANT_ACTION_20210419..
# ..FILTER_ADDED_20210419..
# ..MY_FAVS_REMOVE_RESTAURANT_20210419..
# ..CARD_SWIPE_20210419..
# ..RESTAURANT_FAVOURITE_20210419..
# ..MY_FAVS_FILTER_ADDED_20210419..
# ..HOME_FILTERS_20210419..
# In this folder there are 8 df:
# ['RESTAURANT_ACTION_20210427', 'CARD_SWIPE_20210427', 'MY_FAVS_REMOVE_RESTAURANT_20210427', 'MY_FAVS_FILTER_ADDED_20210427', 'HOME_FILTERS_20210427', 'RESTAURANT_FAVOURITE_20210427', 'view_item_20210427', 'FILTER_ADDED_20210427']
# ..RESTAURANT_ACTION_20210427..
# ..CARD_SWIPE_20210427..
# ..MY_FAVS_REMOVE_RESTAURANT_20210427..
# ..MY_FAVS_FILTER_ADDED_20210427..
# ..HOME_FILTERS_20210427..
# ..RESTAURANT_FAVOURITE_20210427..
# ..view_item_20210427..
# ..FILTER_ADDED_20210427..
# In this folder there are 8 df:
# ['FILTER_ADDED_20210418', 'HOME_FILTERS_20210418', 'MY_FAVS_REMOVE_RESTAURANT_20210418', 'view_item_20210418', 'MY_FAVS_FILTER_ADDED_20210418', 'CARD_SWIPE_20210418', 'RESTAURANT_ACTION_20210418', 'RESTAURANT_FAVOURITE_20210418']
# ..FILTER_ADDED_20210418..
# ..HOME_FILTERS_20210418..
# ..MY_FAVS_REMOVE_RESTAURANT_20210418..
# ..view_item_20210418..
# ..MY_FAVS_FILTER_ADDED_20210418..
# ..CARD_SWIPE_20210418..
# ..RESTAURANT_ACTION_20210418..
# ..RESTAURANT_FAVOURITE_20210418..
# In this folder there are 8 df:
# ['MY_FAVS_REMOVE_RESTAURANT_20210420', 'HOME_FILTERS_20210420', 'CARD_SWIPE_20210420', 'RESTAURANT_FAVOURITE_20210420', 'FILTER_ADDED_20210420', 'view_item_20210420', 'RESTAURANT_ACTION_20210420', 'MY_FAVS_FILTER_ADDED_20210420']
# ..MY_FAVS_REMOVE_RESTAURANT_20210420..
# ..HOME_FILTERS_20210420..
# ..CARD_SWIPE_20210420..
# ..RESTAURANT_FAVOURITE_20210420..
# ..FILTER_ADDED_20210420..
# ..view_item_20210420..
# ..RESTAURANT_ACTION_20210420..
# ..MY_FAVS_FILTER_ADDED_20210420..
# In this folder there are 7 df:
# ['HOME_FILTERS_20210416', 'RESTAURANT_ACTION_20210416', 'MY_FAVS_REMOVE_RESTAURANT_20210416', 'CARD_SWIPE_20210416', 'FILTER_ADDED_20210416', 'RESTAURANT_FAVOURITE_20210416', 'view_item_20210416']
# ..HOME_FILTERS_20210416..
# ..RESTAURANT_ACTION_20210416..
# ..MY_FAVS_REMOVE_RESTAURANT_20210416..
# ..CARD_SWIPE_20210416..
# ..FILTER_ADDED_20210416..
# ..RESTAURANT_FAVOURITE_20210416..
# ..view_item_20210416..
# In this folder there are 8 df:
# ['view_item_20210429', 'MY_FAVS_REMOVE_RESTAURANT_20210429', 'FILTER_ADDED_20210429', 'CARD_SWIPE_20210429', 'RESTAURANT_ACTION_20210429', 'HOME_FILTERS_20210429', 'MY_FAVS_FILTER_ADDED_20210429', 'RESTAURANT_FAVOURITE_20210429']
# ..view_item_20210429..
# ..MY_FAVS_REMOVE_RESTAURANT_20210429..
# ..FILTER_ADDED_20210429..
# ..CARD_SWIPE_20210429..
# ..RESTAURANT_ACTION_20210429..
# ..HOME_FILTERS_20210429..
# ..MY_FAVS_FILTER_ADDED_20210429..
# ..RESTAURANT_FAVOURITE_20210429..

# %% [markdown]
# Concatenating all data obtaining the full dataframe from $1^{th}$ of march march to $31^{th}$ of april

# %%
wee3_1 = pd.read_csv('week_01abr_07abr.csv', index_col=0)
wee3_2 = pd.read_csv('week_08abr_15abr.csv', index_col=0)
wee3_3 = pd.read_csv('week_16abr_31abr.csv', index_col=0)
month2 = pd.concat([wee3_1,wee3_2,wee3_3]).reset_index(drop=True)
month1 = pd.read_csv('week_01mar_31mar.csv', index_col=0)
full_data = pd.concat([month1,month2]).reset_index(drop=True)
full_data.to_csv('week_01mar_30abr.csv')

# %%
pd.read_csv('week_01mar_30abr.csv', index_col=0).head()
# Out:
#   event_name   event_timestamp                    user_pseudo_id  \
# 0  view_item  1615122075978494  cf787fe9a8f5cd3d0a7119e296920e96
# 1  view_item  1615122002536876  cf787fe9a8f5cd3d0a7119e296920e96
# 2  view_item  1615148229440659  C42314CB72C146BFB3A8A447A1F13F1A
# 3  view_item  1615152930412024  C42314CB72C146BFB3A8A447A1F13F1A
# 4  view_item  1615152981578048  C42314CB72C146BFB3A8A447A1F13F1A
#
#   firebase_screen_string_value name_string_value type_string_value  \
# 0            RestaurantDetails      Coquetto Bar               NaN
# 1            RestaurantDetails      Coquetto Bar               NaN
# 2            RestaurantDetails   El Señor Martín               NaN
# 3            RestaurantDetails         La Catapa               NaN
# 4            RestaurantDetails          La Monte               NaN
#
#   action_string_value vibes_string_value dir_string_value
# 0                 NaN                NaN              NaN
# 1                 NaN                NaN              NaN
# 2                 NaN                NaN              NaN
# 3                 NaN                NaN              NaN
# 4                 NaN                NaN              NaN

# %% [markdown]
# ### Useful functions to download data from the app

# %%
def open_app_datas(dir_path):
    """ To Download Init Data """
    def save_Datos(name, dir_path):
        file_path = dir_path + '/' + name + '.csv' 
        return pd.read_csv(file_path)

    list_of_df = []
    for filename_csv in os.listdir(dir_path):
        if filename_csv.endswith(".csv"):
            filename = os.path.splitext(filename_csv)[0]
            globals()[filename + '_' + dir_path] = save_Datos(filename, dir_path)
            list_of_df.append(filename + '_' + dir_path)
    
    return list_of_df

# %% [markdown]
# open_app_datas gives all the dataframes contained in a folder of the form 'Datos_Init_dd_mm_yyyy', generating global variables of the dataframes

# %%
list_data_init = open_app_datas('Datos_Init_01_05_2021')
list_data_init
# Out:
# ['homes__first_action_neighborhoods_Datos_Init_01_05_2021',
#  'reservations_Datos_Init_01_05_2021',
#  'strapi_permission_Datos_Init_01_05_2021',
#  'homes__second_action_food_types_Datos_Init_01_05_2021',
#  'homes__second_action_neighborhoods_Datos_Init_01_05_2021',
#  'homes_Datos_Init_01_05_2021',
#  'profiles__vibes_Datos_Init_01_05_2021',
#  'push_tokens_Datos_Init_01_05_2021',
#  'components_restaurants_promoteds_Datos_Init_01_05_2021',
#  'vibe_Datos_Init_01_05_2021',
#  'neighborhoods_Datos_Init_01_05_2021',
#  'profiles_Datos_Init_01_05_2021',
#  'homes__first_action_food_types_Datos_Init_01_05_2021',
#  'restaurants_components_Datos_Init_01_05_2021',
#  'homecards__vibes_Datos_Init_01_05_2021',
#  'foodtypes_Datos_Init_01_05_2021',
#  'users-permissions_permission_Datos_Init_01_05_2021',
#  'homecards_Datos_Init_01_05_2021',
#  'profiles__food_types_Datos_Init_01_05_2021',
#  'strapi_webhooks_Datos_Init_01_05_2021',
#  'profiles__favorites_Datos_Init_01_05_2021',
#  'profiles__push_tokens_Datos_Init_01_05_2021',
#  'app_homes__home_cards_Datos_Init_01_05_2021',
#  'homes__second_action_vibes_Datos_Init_01_05_2021',
#  'homecards__food_types_Datos_Init_01_05_2021',
#  'strapi_users_roles_Datos_Init_01_05_2021',
#  'strapi_role_Datos_Init_01_05_2021',
#  'homecards__neighborhoods_Datos_Init_01_05_2021',
#  'core_store_Datos_Init_01_05_2021',
#  'cities_Datos_Init_01_05_2021',
#  'permissions_role_Datos_Init_01_05_2021',
#  'vibes_Datos_Init_01_05_2021',
#  'permissions_user_Datos_Init_01_05_2021',
#  'homecards__localizations_Datos_Init_01_05_2021',
#  'promos_Datos_Init_01_05_2021',
#  'components_restaurants_promoteds__vibes_Datos_Init_01_05_2021',
#  'locales_Datos_Init_01_05_2021',
#  'components_restaurants_promoteds__food_types_Datos_Init_01_05_2021',
#  'promos__vibes_Datos_Init_01_05_2021',
#  'components_restaurants_information_Datos_Init_01_05_2021',
#  'promos__food_types_Datos_Init_01_05_2021',
#  'app_homes_Datos_Init_01_05_2021',
#  'homes__first_action_vibes_Datos_Init_01_05_2021',
#  'restaurants__vibes_Datos_Init_01_05_2021',
#  'upload_file_morph_Datos_Init_01_05_2021',
#  'upload_file_Datos_Init_01_05_2021',
#  'components_restaurants_cover_managers_Datos_Init_01_05_2021',
#  'restaurants__food_types_Datos_Init_01_05_2021',
#  'components_restaurants_geolocations_Datos_Init_01_05_2021',
#  'profiles__blacklist_Datos_Init_01_05_2021',
#  'cities__neighborhoods_Datos_Init_01_05_2021',
#  'strapi_administrator_Datos_Init_01_05_2021',
#  'promos__neighborhoods_Datos_Init_01_05_2021',
#  'restaurants_Datos_Init_01_05_2021']

# %%
restaurants_Datos_Init_01_05_2021.head()
# Out:
#     id                  name              chef                        price  \
# 0  312                  CORE       Clare Smyth          £125 (Tasting Menu)
# 1  313     C. B. at Bibendum       Claude Bosi          £185 (Tasting Menu)
# 2  314  Le Bistroman Atelier  Stephane del Rio  Entre 60€ y 70€ por persona
# 3  315            Mediamanga       Iván Castro               50€ per person
# 4  316           Zoko Madrid      Javi Álvarez                       40€ pp
#
#                       specialDish       phoneNumber  \
# 0                             NaN  +44 20 3937 5086
# 1                             NaN  +44 20 7629 8866
# 2       Filet de boeuf Wellington   +34 914 47 2713
# 3           Gambita frita ahumada  +34 938 32 56 94
# 4  Empanada de atún en 3 texturas  +34 911 44 93 69
#
#                                              bookUrl  \
# 0  https://www.opentable.co.uk/widget/reservation...
# 1  https://www.opentable.com/restref/client/?rid=...
# 2  https://module.lafourchette.com/es_ES/module/5...
# 3  http://www.mediamanga.es/booking/reservar_mesa...
# 4  https://module.lafourchette.com/es_ES/module/5...
#
#                                       instagramUrl  \
# 0      https://www.instagram.com/corebyclaresmyth/
# 1  https://www.instagram.com/claudebosiatbibendum/
# 2     https://www.instagram.com/bistroman_atelier/
# 3         https://www.instagram.com/mediamangabcn/
# 4            https://www.instagram.com/zokomadrid/
#
#                             chefInstagramUrl  \
# 0  https://www.instagram.com/chefclaresmyth/
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  https://www.instagram.com/chefjavieralvz/
#
#                                   mapUrl  \
# 0  https://goo.gl/maps/N84LNnitrspS8N4M7
# 1  https://goo.gl/maps/MSWVZ2RG8iQYTtpa9
# 2  https://goo.gl/maps/em4dmjg6rBWDrY7s7
# 3  https://goo.gl/maps/9QPLh7TGRfmYKeBx8
# 4  https://goo.gl/maps/pbqTsSnL5NMc9bjP8
#
#                                             website       curated_by  \
# 0                 https://www.corebyclaresmyth.com/              NaN
# 1                           https://claudebosi.com/              NaN
# 2                           https://lebistroman.es/  Gastro Godzilla
# 3                     https://www.mediamanga.es/es/    Equipo Velada
# 4  https://restaurantezoko.com/project/zoko-madrid/    Equipo Velada
#
#                        curatedByInstagramUrl deliveryBy  \
# 0                                        NaN        NaN
# 1                                        NaN        NaN
# 2  https://www.instagram.com/gastrogodzilla/   Teléfono
# 3                                        NaN        NaN
# 4      https://www.instagram.com/velada.app/   Web Zoko
#
#                                          deliveryUrl  \
# 0                                                NaN
# 1                                                NaN
# 2         https://lebistroman.es/servicio-domicilio/
# 3                                                NaN
# 4  https://us12.eveve.com/takeaway/?est=zoko&coun...
#
#                                              menuUrl  isHidden  isPromoted  \
# 0                                                NaN         0           0
# 1                                                NaN         0           0
# 2                 https://lebistroman.es/restaurant/         0           0
# 3                                                NaN         0           0
# 4  https://restaurantezoko.com/wp-content/uploads...         0           0
#
#    stars             legacy_id         published_at  created_by  updated_by  \
# 0    2.0  036N28qoaexuxy0eYN9C  2021-01-20 16:49:34         NaN         1.0
# 1    2.0  0adXSSSDDoWvPiVmhp9g  2021-01-20 16:49:36         NaN         1.0
# 2    0.0  1BRW2NZrs1srK2ZVHFit  2021-01-20 16:49:38         NaN         1.0
# 3    0.0  1IAul9VsCfKiLzb0MaU3  2021-01-20 16:49:40         NaN         1.0
# 4    0.0  1LItQJBULz2AmqslBLSX  2021-01-20 16:49:42         NaN         1.0
#
#             created_at           updated_at  neighborhood  city  reservation  \
# 0  2021-01-20 16:49:34  2021-04-26 15:11:59           NaN   NaN          NaN
# 1  2021-01-20 16:49:36  2021-04-26 15:14:47           NaN   NaN          NaN
# 2  2021-01-20 16:49:38  2021-04-26 14:56:31          40.0   4.0          NaN
# 3  2021-01-20 16:49:40  2021-04-26 14:52:28          31.0   5.0          NaN
# 4  2021-01-20 16:49:42  2021-04-26 14:42:51          28.0   4.0          NaN
#
#                    slug
# 0                  core
# 1       c-b-at-bibendum
# 2  le-bistroman-atelier
# 3            mediamanga
# 4           zoko-madrid
